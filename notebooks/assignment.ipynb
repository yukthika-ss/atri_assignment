# %% [markdown]
# <a href="https://colab.research.google.com/github/yukthika-ss/atri_assignment/blob/main/notebooks/assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Question 1
# Load Fashion-MNIST and visualize one sample image from each class

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import fashion_mnist

# %%
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (60000, 28, 28)
# (60000,)

# %%
class_names = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot"
]

# %%
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
axes = axes.flatten()
for class_index in range(10):

    image_index = np.where(y_train == class_index)[0][0]

    image = x_train[image_index]

    axes[class_index].imshow(image, cmap="gray")

    axes[class_index].set_title(class_names[class_index])

    axes[class_index].axis("off")
plt.tight_layout()
plt.show()
